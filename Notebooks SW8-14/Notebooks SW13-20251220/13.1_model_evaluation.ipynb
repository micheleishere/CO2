# %% [markdown]
# # Regression models

# %%
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %% [raw]
# # Many different scoring metrices can be calculated
# # by sklearn's cross_val_score() function.
# #
# # For regression the most common is the "root mean squared error (RMSE)".

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

X, y = datasets.load_diabetes(return_X_y=True)

model = LinearRegression()

cross_val_score(model, X, y, cv=3, scoring='neg_root_mean_squared_error')
# Out:
# array([-55.08394885, -57.03688847, -52.85825094])

# %% [raw]
# # The only reason it returns the negative RMSE is so that
# # "bigger is better" ranking works for all metrices the same.

# %%
# r2 score popular from statistics can also be reported
cross_val_score(model, X, y, cv=3, scoring='r2')
# Out:
# array([0.46930418, 0.48725261, 0.50954961])

# %% [markdown]
# # Classification Models

# %% [raw]
# # For classification problems we usually use 'Accuracy'

# %%
from sklearn.metrics import accuracy_score

y_pred = [0, 2, 1, 3]
y_true = [0, 1, 2, 3]

accuracy_score(y_true, y_pred)
# Out:
# 0.5

# %%
# You can calculate the F1-Score as follows:

# %%
from sklearn.metrics import f1_score

y_pred = [0, 1, 1, 0]
y_true = [0, 1, 0, 1]

f1_score(y_true, y_pred)
# Out:
# 0.5

# %% [raw]
# # The confusion matrix consists of the
# # - true positives,
# # - false negatives,
# # - false positives, and
# # - true negatives
# # values.

# %%
from sklearn.metrics import confusion_matrix

y_pred = [0, 1, 1, 0]
y_true = [0, 1, 1, 1]

cm = confusion_matrix(y_true, y_pred)

print('Confusion matrix:\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('True Negatives(TN) = ', cm[1,1])
print('False Positives(FP) = ', cm[0,1])
print('False Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix:
#  [[1 0]
#  [1 2]]
#
# True Positives(TP) =  1
# True Negatives(TN) =  2
# False Positives(FP) =  0
# False Negatives(FN) =  1

# %% [raw]
# # You can display the confusion matrix graphically e.g. as follows:

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

X, y = make_classification(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y)

clf = SVC().fit(X_train, y_train)

predictions = clf.predict(X_test)

cm = confusion_matrix(y_test, predictions, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
disp.plot();

# %% [raw]
# # More detailed classification statistics are provided by
# # the classification_report() function.
# # Especially for unbalanced data it is recommended to check
# # the performance seperately per target class.

# %%
from sklearn.metrics import classification_report

y_true = [0, 1, 2, 2, 2]
y_pred = [0, 0, 2, 2, 1]

target_names = ['class 0', 'class 1', 'class 2']

print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.50      1.00      0.67         1
#      class 1       0.00      0.00      0.00         1
#      class 2       1.00      0.67      0.80         3
#
#     accuracy                           0.60         5
#    macro avg       0.50      0.56      0.49         5
# weighted avg       0.70      0.60      0.61         5

# %% [raw]
# # The most important plot to look at for classfication problems
# # is the ROC curve:

# %%
from sklearn.metrics import roc_curve
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

X, y = make_classification(n_samples=10000)

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = KNeighborsClassifier().fit(X_train, y_train)
y_pred = model.predict_proba(X_test)

fpr, tpr, thresholds = roc_curve(y_test, y_pred[:,1])

def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label) 
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

plot_roc_curve(fpr, tpr)

# %%
for a,b,c in zip(thresholds, fpr, tpr):
    print(a,b,c)
# Out:
# inf 0.0 0.0
# 1.0 0.012038523274478331 0.539872408293461
# 0.8 0.04173354735152488 0.7631578947368421
# 0.6 0.10754414125200643 0.8644338118022329
# 0.4 0.2158908507223114 0.9322169059011164
# 0.2 0.4478330658105939 0.9752791068580542
# 0.0 1.0 1.0

# %% [raw]
# # Finally, here is how to compute the
# # area under the ROC curve (AUC):

# %%
from sklearn.metrics import roc_auc_score
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

X, y = make_classification(random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = SVC().fit(X_train, y_train)

roc_auc_score(y_test, model.predict(X_test))
# Out:
# 0.9

# %%
# More performance metrics at:
# https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
# --->> Your Turn <<<---
# plot the precision-recall curve 
# and caluclate the AUC-PR for a random forest classifier
# and precision, recall and f1 as a function of the threshold

# %%
# --->> Your Turn <<<---
# plot precision, recall and f1 as a function of the threshold

# %%
# --->> Your Turn <<<---
# How would you shift the decision threshold if
# a) the cost of false negatives is much higher than the cost of false positives?
# b) the cost of false positives is much higher than the cost of false negatives?
