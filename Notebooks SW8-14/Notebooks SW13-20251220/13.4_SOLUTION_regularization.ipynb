# %% [markdown]
# # Regularization

# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, root_mean_squared_error
import matplotlib.pyplot as plt

# %%
# get the data
X_data, y_data = fetch_california_housing(return_X_y=True)
X_data.shape
# Out:
# (20640, 8)

# %%
# choose a random subset of the data to increase overfitting
N=7000
np.random.seed(42)
subset_indices = np.random.choice(X_data.shape[0], size=N, replace=False)
X_data = X_data[subset_indices]
y_data = y_data[subset_indices]

# %%
# add polynomial features and interactions to increase complexity (and overfitting)
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=False)
X_data = poly.fit_transform(X_data)
X_data.shape
# Out:
# (7000, 164)

# %%
# create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=42)

print('shape of X :', X_data.shape, 'shape of Y :', y_data.shape)
print('shape of X-train :', X_train.shape, 'shape of Y-train :', y_train.shape)
print('shape of X-test :', X_test.shape, 'shape of Y-test :', y_test.shape)
# Out:
# shape of X : (7000, 164) shape of Y : (7000,)
# shape of X-train : (4900, 164) shape of Y-train : (4900,)
# shape of X-test : (2100, 164) shape of Y-test : (2100,)

# %% [markdown]
# # Lasso model

# %%
from sklearn.linear_model import Lasso

alpha = 0.1
model_lasso = Lasso(alpha=alpha)
print(model_lasso)
# Out:
# Lasso(alpha=0.1)

# %%
# train the lasso model
model_lasso.fit(X_train, y_train)

y_pred_lasso = model_lasso.predict(X_test)
# Out:
# /Users/nyfe/anaconda3/envs/MLCO2_test/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.383e+02, tolerance: 6.555e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.metrics import r2_score
print("r^2 of lasso on test data : %f" % r2_score(y_test, y_pred_lasso))
print("rmse of lasso on test data : %f" % root_mean_squared_error(y_test, y_pred_lasso))
# Out:
# r^2 of lasso on test data : 0.698201
# rmse of lasso on test data : 0.632350

# %% [markdown]
# # ElasticNet model

# %%
from sklearn.linear_model import ElasticNet

model_elastic = ElasticNet(alpha=alpha, l1_ratio=0.3)
print(model_elastic)
# Out:
# ElasticNet(alpha=0.1, l1_ratio=0.3)

# %%
model_elastic.fit(X_train, y_train)
y_pred_elastic = model_elastic.predict(X_test)
print("r^2 on test data : %f" % r2_score(y_test, y_pred_elastic))
print("rmse on test data : %f" % root_mean_squared_error(y_test, y_pred_elastic))
# Out:
# r^2 on test data : 0.689710
# rmse on test data : 0.641184
# /Users/nyfe/anaconda3/envs/MLCO2_test/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.263e+02, tolerance: 6.555e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
# get true coefficients of linear regression on the test set
from sklearn.linear_model import LinearRegression
model_true = LinearRegression().fit(X_test, y_test)
model_true.coef_
# Out:
# array([-1.59845792e-04,  4.11997396e-03, -1.06020159e-03,  1.68564050e-03,
#        -2.13934978e-01,  1.92908048e-03,  1.27326927e-03,  2.79371523e-04,
#         1.29800583e-02, -1.16799193e-01,  9.45643540e-03,  5.82781779e-03,
#        -2.83041497e-03,  1.31748481e-02, -1.08451562e-02,  1.69682667e-02,
#        -9.62893661e-04,  1.44526490e-01,  5.48779737e-02, -2.17044397e-04,
#        -3.94535342e-02, -1.24014673e-01, -3.29515104e-02, -9.18474323e-02,
#        -1.15907969e-02,  3.70159034e-03,  8.37315215e-03,  1.27073562e-03,
#         4.55621397e-02, -1.68589708e-03,  2.83253991e-02,  8.44463914e-03,
#         3.93533668e-02, -1.05860825e-01, -3.53006445e-07, -3.10593269e-03,
#        -6.81806890e-03, -5.44624200e-03,  3.95606856e-03,  4.40180949e-02,
#        -1.22981502e-01,  7.48072083e-02, -8.17635975e-02, -3.54518817e-02,
#        -4.65483312e-03, -7.95699125e-04,  2.83727260e-03, -1.09413000e-01,
#        -1.53191609e-05,  4.60185586e-04, -1.57576185e-02, -6.22161314e-03,
#        -1.14794515e-04,  6.96888359e-04,  1.79638020e-02, -1.39887835e-06,
#        -3.06199769e-03, -1.74233125e-03, -1.55046972e-03,  8.24439711e-03,
#        -4.84164248e-02,  3.12313200e-05,  2.88733404e-02,  3.22490502e-02,
#         1.13660539e-02, -4.22197633e-02,  2.67509054e-04, -4.29263303e-01,
#        -1.42154092e-01, -5.96967081e-02, -1.73088048e-08,  5.00677023e-05,
#        -3.05439503e-05, -3.02453601e-05, -2.33338826e-03,  1.51193403e-02,
#         2.69901998e-03, -1.20860579e-02, -7.50011660e-03, -1.08531744e-03,
#         2.09173503e-05,  2.57281470e-04, -4.27101296e-04,  1.92891152e-07,
#         3.28438224e-06, -2.32738923e-05,  4.40224588e-06, -1.29267748e-03,
#         5.41048160e-03,  2.50775417e-06,  5.75342886e-03,  2.16021768e-03,
#         2.11931441e-03,  3.69087043e-03, -4.39082581e-06, -2.43925283e-02,
#         4.09484205e-03,  1.60537118e-03,  2.30962013e-10,  2.12282025e-06,
#        -2.06492905e-06, -2.27474378e-06,  2.61829604e-03,  2.16906640e-03,
#         4.43229225e-04, -1.37436187e-03, -1.70491789e-03, -3.41542629e-04,
#        -7.27608584e-03,  7.09703970e-02, -1.22805828e-05, -2.16274189e-02,
#        -1.01164992e-02, -5.39428211e-03, -1.54293323e-01, -5.03045184e-05,
#         2.14824066e-01,  6.12398396e-02,  3.24956041e-02,  2.24788074e-08,
#        -3.24614885e-05,  4.98781888e-05,  4.65477382e-05,  2.05837922e-02,
#         6.95865344e-03,  4.66963537e-03,  2.33268246e-02,  1.54199449e-02,
#         2.98117502e-03, -6.56492313e-02,  7.11459313e-04,  9.50753357e-02,
#         1.15908463e-01,  1.91422744e-02, -1.35015337e-07,  1.41858925e-04,
#         4.60866458e-04,  3.92610135e-04,  3.74694346e-02, -3.00210379e-01,
#        -9.12113576e-02, -1.35835050e-01, -8.38295922e-02, -1.38824118e-02,
#        -2.26146359e-13,  1.67723320e-08, -7.79688822e-09, -5.57632978e-09,
#        -1.29326236e-05, -3.86429543e-06, -2.55553541e-05, -4.39409157e-05,
#        -7.89645161e-05, -3.30430191e-05, -1.36382845e-02, -2.62460595e-02,
#        -8.50073282e-03, -1.21700465e-02, -1.11114030e-02, -3.38561185e-03,
#         9.00280113e-03,  6.88214874e-03,  5.93243391e-04, -2.32712877e-04])

# %% [markdown]
# ## linear Model without regularisation

# %%
model_linear = LinearRegression().fit(X_train, y_train)
y_pred_linear = model_linear.predict(X_test)
print("r^2 on test data : %f" % r2_score(y_test, y_pred_linear))
print("rmse on test data : %f" % root_mean_squared_error(y_test, y_pred_linear))
# Out:
# r^2 on test data : 0.219960
# rmse on test data : 1.016616

# %% [markdown]
# # Ridge regression model

# %%
# --->>> Your turn <<<---
# Add a Ridge regression model
# How does it compare to the others?

from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

alpha = 0.1
model_ridge = Ridge(alpha=alpha)
print(model_ridge)

# train the model
model_ridge.fit(X_train, y_train)

y_pred_ridge = model_ridge.predict(X_test)

print("r^2 of ridge on test data : %f" % r2_score(y_test, y_pred_ridge))
print("rmse of ridge on test data : %f" % root_mean_squared_error(y_test, y_pred_ridge))
# Out:
# Ridge(alpha=0.1)
# r^2 of ridge on test data : 0.454409
# rmse of ridge on test data : 0.850221
# /Users/nyfe/anaconda3/envs/MLCO2_test/lib/python3.12/site-packages/scipy/_lib/_util.py:1226: LinAlgWarning: Ill-conditioned matrix (rcond=1.27156e-27): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)

# %% [markdown]
# ## Compare the different Models

# %%
# Compare the coefficients of the models

# A stem plot draws lines perpendicular to a baseline
# and places a marker there.

m, s, _ = plt.stem(np.where(model_elastic.coef_)[0],
                   model_elastic.coef_[model_elastic.coef_ != 0],
                   markerfmt='bo', label='Elastic net coefficients')
plt.setp([m, s], color="green")

m, s, _ = plt.stem(np.where(model_lasso.coef_)[0],
                   model_lasso.coef_[model_lasso.coef_ != 0],
                   markerfmt='x', label='Lasso coefficients')
plt.setp([m, s], color='red')

m, s, _ = plt.stem(np.where(model_ridge.coef_)[0],
                   model_ridge.coef_[model_ridge.coef_ != 0],
                   markerfmt='s', label='Ridge coefficients')
plt.setp([m, s], color='y')

m, s, _ = plt.stem(np.where(model_linear.coef_)[0],
                   model_linear.coef_[model_linear.coef_ != 0],
                   markerfmt='x', label='Linear coefficients')
plt.setp([m, s], color='green')

plt.stem(np.where(model_true.coef_)[0],
         model_true.coef_[model_true.coef_ != 0],
         label='true coefficients',
         markerfmt='bx')

plt.legend()
plt.title(f"Lasso $R^2$: %.3f \n "
          f"Elastic Net $R^2$: %.3f \n"
          f"Ridge $R^2$: %.3f \n"
          f"Linear $R^2$: %.3f" % (
            r2_score(y_test, y_pred_lasso),
            r2_score(y_test, y_pred_elastic),
            r2_score(y_test, y_pred_ridge),
            r2_score(y_test, y_pred_linear)))
# Out:
# Text(0.5, 1.0, 'Lasso $R^2$: 0.698 \n Elastic Net $R^2$: 0.690 \nRidge $R^2$: 0.454 \nLinear $R^2$: 0.220')

# %% [markdown]
# ## Using noise in training as regularisation

# %%
from copy import deepcopy
X_train_noise = deepcopy(X_train)
noise_amount = 0.01
#adding noise to a copy of the training data
np.random.seed(42)
for feature in range(X_train.shape[1]):
    X_train_noise[:,feature] = (1-noise_amount)*X_train[:,feature] + \
      noise_amount*np.random.normal(loc=0, scale=np.std(X_train[:,feature]), size=X_train[:,feature].shape)

# %%
# get true coefficients of unregularised linear regression on the test set
model_noise = LinearRegression().fit(X_train_noise, y_train)
y_pred_noise = model_noise.predict(X_test)
print("r^2 on test data : %f" % r2_score(y_test, y_pred_noise))
print("rmse on test data : %f" % root_mean_squared_error(y_test, y_pred_noise))
# Out:
# r^2 on test data : 0.635348
# rmse on test data : 0.695085

# %%
# Compare the coefficients of the models

# A stem plot draws lines perpendicular to a baseline
# and places a marker there.

m, s, _ = plt.stem(np.where(model_elastic.coef_)[0], 
                   model_elastic.coef_[model_elastic.coef_ != 0],
                   markerfmt='bo', label='Elastic net coefficients')
plt.setp([m, s], color="green")

m, s, _ = plt.stem(np.where(model_lasso.coef_)[0], 
                   model_lasso.coef_[model_lasso.coef_ != 0],
                   markerfmt='x', label='Lasso coefficients')
plt.setp([m, s], color='red')

m, s, _ = plt.stem(np.where(model_ridge.coef_)[0], 
                   model_ridge.coef_[model_ridge.coef_ != 0],
                   markerfmt='s', label='Ridge coefficients')
plt.setp([m, s], color='y')

m, s, _ = plt.stem(np.where(model_noise.coef_)[0], 
                   model_noise.coef_[model_noise.coef_ != 0],
                   markerfmt='x', label='Noise coefficients')
plt.setp([m, s], color='black')

plt.stem(np.where(model_true.coef_)[0], 
         model_true.coef_[model_true.coef_ != 0], 
         label='true coefficients',
         markerfmt='bx')

plt.legend()
plt.title(f"Lasso $R^2$: %.3f \n "
          f"Elastic Net $R^2$: %.3f \n"
          f"Ridge $R^2$: %.3f \n"
          f"Linear $R^2$: %.3f \n" 
          f"Linear with Noise $R^2$: %.3f" % (
            r2_score(y_test, y_pred_lasso),
            r2_score(y_test, y_pred_elastic),
            r2_score(y_test, y_pred_ridge),
            r2_score(y_test, y_pred_linear),
            r2_score(y_test, y_pred_noise)))
# Out:
# Text(0.5, 1.0, 'Lasso $R^2$: 0.698 \n Elastic Net $R^2$: 0.690 \nRidge $R^2$: 0.454 \nLinear $R^2$: 0.220 \nLinear with Noise $R^2$: 0.635')
