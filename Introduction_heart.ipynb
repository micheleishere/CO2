# %% [markdown]
# # Data Challenge Project Work CO2
#
# ## Introduction
#
# ###### Ka Men Ho, Luana Aido da Silva, Michèle Pfister
#
# Explain the task to be solved.
#
# • Point out, possibly, related work or problems in the literature/internet with links/
# references to the sources

# %% [markdown]
# #### Sources
#
# ssad
